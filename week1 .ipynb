# %% [markdown]
# ## Technology Innovetion Project
# * Name: Krishma Krishma
# * Student ID: 104659684
# * Email: 104659684@student.swin.edu.au

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Loading

# %%
data = pd.read_csv('fraudTest.csv')
print("data shape:", data.shape)
print(data.info())
print(data.columns)
print(data.index)
# Out:
# data shape: (555719, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
# ...

# %%
# show first and last five rows of the data 
print(data.head(5))
print(data.tail(5))
print(data.dtypes)
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0       6/21/2020 12:14  2.291164e+15
# 1           1       6/21/2020 12:14  3.573030e+15
# 2           2       6/21/2020 12:14  3.598215e+15
# 3           3       6/21/2020 12:15  3.591920e+15
# 4           4       6/21/2020 12:15  3.526826e+15
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# 1  Williams      F             3638 Marsh Union  ...  40.3207 -110.4360
# ...

# %%
# Check for missing values in each column
missing_values = data.isnull().sum()
print(missing_values)
missing_values_counts = data.isnull().sum(axis=1)
print(missing_values_counts)
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 555714    0
# 555715    0
# 555716    0
# 555717    0
# 555718    0
# Length: 555719, dtype: int64

# %%
# Fill the missing values with mean values
mean_values = data.mean(numeric_only=True)
data = data.fillna(mean_values)
print(mean_values)
print(data)
# Out:
# Unnamed: 0    2.778590e+05
# cc_num        4.178387e+17
# amt           6.939281e+01
# zip           4.884263e+04
# lat           3.854325e+01
# long         -9.023133e+01
# city_pop      8.822189e+04
# unix_time     1.380679e+09
# merch_lat     3.854280e+01
# merch_long   -9.023138e+01
# is_fraud      3.859864e-03
# dtype: float64
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0       6/21/2020 12:14  2.291164e+15
# 1                1       6/21/2020 12:14  3.573030e+15
# 2                2       6/21/2020 12:14  3.598215e+15
# 3                3       6/21/2020 12:15  3.591920e+15
# 4                4       6/21/2020 12:15  3.526826e+15
# ...            ...                   ...           ...
# 555714      555714      12/31/2020 23:59  3.056060e+13
# 555715      555715      12/31/2020 23:59  3.556613e+15
# 555716      555716      12/31/2020 23:59  6.011724e+15
# 555717      555717      12/31/2020 23:59  4.079770e+12
# ...

# %%
# Check the categorical columns
categorical_columns = data.select_dtypes(include='object').columns
print(categorical_columns)
# Out:
# Index(['trans_date_trans_time', 'merchant', 'category', 'first', 'last',
#        'gender', 'street', 'city', 'state', 'job', 'dob', 'trans_num'],
#       dtype='object')

# %%
# check for the duplicate values
data.drop_duplicates = data[data.duplicated(keep='first')]
data_rows, data_columns = data.shape
print(data_rows)
print(data_columns)
# Out:
# 555719
# 23

# %%
# Out:
#         amt       lat      long  city_pop  merch_lat  merch_long
# 0 -0.424463 -0.904377  0.677451  0.816521  -0.894145    0.657586
# 1 -0.252337  0.351182 -1.472454 -0.292685   0.178126   -1.436610
# 2 -0.179353  0.420768  1.216667 -0.178853   0.383257    1.167640
# 3 -0.059605 -1.970539  0.685934 -0.111371  -1.909485    0.680717
# 4 -0.422358  1.128092  0.380004 -0.289942   1.259139    0.316510

# %%
# Separate fraudulent transactions and legitimate transactions
fraud_data = data[data1['is_fraud'] == 1]
legit_data = data[data1['is_fraud'] == 0]
print("Fraud Data", fraud_data)
print("Legit Data", legit_data)
print("Fraud Data", fraud_data.shape)
print("Legit Data", legit_data.shape)
# Out:
# Fraud Data         Unnamed: 0 trans_date_trans_time        cc_num  \
# 1685          1685       6/21/2020 22:06  3.560725e+15
# 1767          1767       6/21/2020 22:32  6.564460e+15
# 1781          1781       6/21/2020 22:37  6.564460e+15
# 1784          1784       6/21/2020 22:38  4.005677e+15
# 1857          1857       6/21/2020 23:02  3.560725e+15
# ...            ...                   ...           ...
# 517197      517197      12/22/2020 22:05  2.242177e+15
# 517274      517274      12/22/2020 22:18  2.242177e+15
# 517341      517341      12/22/2020 22:31  2.242177e+15
# 517529      517529      12/22/2020 23:06  2.242177e+15
# 517571      517571      12/22/2020 23:13  2.242177e+15
#
#                                    merchant        category       amt  \
# 1685                   fraud_Hamill-D'Amore  health_fitness -0.284236
# 1767      fraud_Rodriguez, Yost and Jenkins        misc_net  4.536818
# 1781                       fraud_Nienow PLC   entertainment  3.514845
# ...

# %%
new_dataset = data1 = pd.concat([fraud_data, legit_data], axis=0)
print(data1)
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 1685          1685       6/21/2020 22:06  3.560725e+15
# 1767          1767       6/21/2020 22:32  6.564460e+15
# 1781          1781       6/21/2020 22:37  6.564460e+15
# 1784          1784       6/21/2020 22:38  4.005677e+15
# 1857          1857       6/21/2020 23:02  3.560725e+15
# ...            ...                   ...           ...
# 555714      555714      12/31/2020 23:59  3.056060e+13
# 555715      555715      12/31/2020 23:59  3.556613e+15
# 555716      555716      12/31/2020 23:59  6.011724e+15
# 555717      555717      12/31/2020 23:59  4.079770e+12
# 555718      555718      12/31/2020 23:59  4.170689e+15
#
#                                    merchant        category       amt  \
# 1685                   fraud_Hamill-D'Amore  health_fitness -0.284236
# 1767      fraud_Rodriguez, Yost and Jenkins        misc_net  4.536818
# 1781                       fraud_Nienow PLC   entertainment  3.514845
# ...
