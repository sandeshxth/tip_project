# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import TargetEncoder, LabelEncoder
from datetime import datetime

# %%
# displays all columns 
pd.set_option('display.max_columns', None)

# %%
def calculate_age(dob):
    today = datetime.today()
    return today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))

# %% [markdown]
# ### Calculate distance between client and merch where there card was been used

# %%
def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2.0) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    km = 6371 * c
    return km


# Calculate distance and create a new 'distance_km' column
df['dist_client_merch'] = df.apply(lambda row: haversine(row['lat'], row['long'], row['merch_lat'], row['merch_long']), axis=1)

# %%
def data_processing(df_path):
    df = pd.read_csv(df_path)
    df.drop(df.columns[0], axis=1, inplace=True)
    df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
    df['dob'] = pd.to_datetime(df['dob'])
    
    df['year'] = df['trans_date_trans_time'].dt.year
    df['month'] = df['trans_date_trans_time'].dt.month
    df['day'] = df['trans_date_trans_time'].dt.day
    df['time'] = df['trans_date_trans_time'].dt.time
    
    df['time'] = pd.to_datetime(df.time, format='%H:%M:%S')
    
    # Ensure 'dob' is in datetime format
    df['dob'] = pd.to_datetime(df['dob'])

    # Calculate age and create a new 'age' column
    df['age'] = df['dob'].apply(calculate_age)
    
    # Calculate distance and create a new 'distance_km' column
    df['dist_client_merch'] = df.apply(lambda row: haversine(row['lat'], row['long'], row['merch_lat'], row['merch_long']), axis=1)
    
    le = LabelEncoder()
    df['le_gender'] = le.fit_transform(df['gender'])
    
    te = TargetEncoder()
    te_job = te.fit_transform(df['job'].array.reshape(-1, 1), df['is_fraud'])
    df['te_job'] = te_job
    te_street = te.fit_transform(df['street'].array.reshape(-1, 1), df['is_fraud'])
    df['te_street'] = te_street
    te_merchant = te.fit_transform(df['merchant'].array.reshape(-1, 1), df['is_fraud'])
    df['te_merchant'] = te_merchant
    te_city = te.fit_transform(df['city'].array.reshape(-1, 1), df['is_fraud'])
    df['te_city'] = te_city
    te_state = te.fit_transform(df['state'].array.reshape(-1, 1), df['is_fraud'])
    df['te_state'] = te_state
    te_category = te.fit_transform(df['category'].array.reshape(-1, 1), df['is_fraud'])
    df['te_category'] = te_category
    
    return df

# %%
df = data_processing('../fraudTrain.csv')

# %%
df.sample()

# %%
columns_to_drop = [
    'merchant', 'category', 'gender', 'street', 'city', 'state', 'job', 'first', 'last', 'lat', 'long', 'time', 'cc_num', 'trans_date_trans_time', 'trans_num', 'merch_lat', 'merch_long', 'dob'
]

# Create a new DataFrame by dropping the specified columns
df_1 = df.drop(columns=columns_to_drop)

# %%
df_1.sample()
# Out:
#           amt    zip  city_pop   unix_time  is_fraud  year  month  day  age  \
# 170606  46.14  68638      1749  1333168199         0  2019      3   31   51
#
#         dist_client_merch  le_gender    te_job  te_street  te_merchant  \
# 170606          75.153168          0  0.007966   0.008023     0.006914
#
#          te_city  te_state  te_category
# 170606  0.008101  0.007428     0.002718

# %%
df_1.corr()
# Out:
#                         amt       zip  city_pop  unix_time  is_fraud  \
# amt                1.000000  0.001843  0.005818  -0.000293  0.219404
# zip                0.001843  1.000000  0.078467   0.000670 -0.002162
# city_pop           0.005818  0.078467  1.000000  -0.001714  0.002136
# unix_time         -0.000293  0.000670 -0.001714   1.000000 -0.005078
# is_fraud           0.219404 -0.002162  0.002136  -0.005078  1.000000
# year               0.000842  0.000086 -0.001673   0.782582  0.003004
# month             -0.001748  0.000852  0.000137   0.184868 -0.012409
# day                0.000629 -0.000607  0.000159   0.017162  0.003848
# age               -0.009848  0.010044 -0.094120  -0.003636  0.012410
# dist_client_merch -0.001085  0.006183  0.010901  -0.000633  0.000403
# le_gender          0.001034 -0.065951 -0.028649  -0.000960  0.007642
# te_job             0.041144 -0.007478  0.003775  -0.001619  0.170576
# te_street          0.078606 -0.006654  0.006653  -0.003322  0.317534
# te_merchant        0.091825  0.005155  0.000501   0.000255  0.065227
# te_city            0.069979 -0.006126  0.006664  -0.003706  0.281270
# te_state           0.007424 -0.056371 -0.011702  -0.001937  0.036865
# te_category        0.097918  0.005238  0.000572   0.000151  0.070568
#
#                        year     month       day       age  dist_client_merch  \
# amt                0.000842 -0.001748  0.000629 -0.009848          -0.001085
# zip                0.000086  0.000852 -0.000607  0.010044           0.006183
# city_pop          -0.001673  0.000137  0.000159 -0.094120           0.010901
# unix_time          0.782582  0.184868  0.017162 -0.003636          -0.000633
# is_fraud           0.003004 -0.012409  0.003848  0.012410           0.000403
# year               1.000000 -0.464879 -0.045759 -0.004395          -0.000595
# month             -0.464879  1.000000  0.012434  0.002211           0.000098
# day               -0.045759  0.012434  1.000000  0.000575          -0.000594
# age               -0.004395  0.002211  0.000575  1.000000          -0.004626
# dist_client_merch -0.000595  0.000098 -0.000594 -0.004626           1.000000
# le_gender         -0.000654 -0.000215 -0.000206  0.007350          -0.002394
# te_job            -0.004312  0.004570 -0.000415  0.031934           0.001009
# te_street          0.000030 -0.005227  0.005136  0.038531           0.000086
# te_merchant        0.001742 -0.001462  0.000591 -0.001221           0.000588
# te_city            0.000153 -0.005767  0.002809  0.034534          -0.000050
# te_state          -0.001245 -0.001077  0.003606  0.019097          -0.005134
# te_category        0.001585 -0.001332  0.001000 -0.001402           0.001070
#
#                    le_gender    te_job  te_street  te_merchant   te_city  \
# amt                 0.001034  0.041144   0.078606     0.091825  0.069979
# zip                -0.065951 -0.007478  -0.006654     0.005155 -0.006126
# city_pop           -0.028649  0.003775   0.006653     0.000501  0.006664
# unix_time          -0.000960 -0.001619  -0.003322     0.000255 -0.003706
# is_fraud            0.007642  0.170576   0.317534     0.065227  0.281270
# year               -0.000654 -0.004312   0.000030     0.001742  0.000153
# month              -0.000215  0.004570  -0.005227    -0.001462 -0.005767
# day                -0.000206 -0.000415   0.005136     0.000591  0.002809
# age                 0.007350  0.031934   0.038531    -0.001221  0.034534
# dist_client_merch  -0.002394  0.001009   0.000086     0.000588 -0.000050
# le_gender           1.000000  0.021813   0.023715    -0.010502  0.024350
# te_job              0.021813  1.000000   0.539564     0.013412  0.483152
# te_street           0.023715  0.539564   1.000000     0.025764  0.884437
# te_merchant        -0.010502  0.013412   0.025764     1.000000  0.022747
# te_city             0.024350  0.483152   0.884437     0.022747  1.000000
# te_state            0.014390  0.022554   0.117672     0.001786  0.021291
# te_category        -0.010880  0.014038   0.027886     0.931719  0.024351
#
#                    te_state  te_category
# amt                0.007424     0.097918
# zip               -0.056371     0.005238
# city_pop          -0.011702     0.000572
# unix_time         -0.001937     0.000151
# is_fraud           0.036865     0.070568
# year              -0.001245     0.001585
# month             -0.001077    -0.001332
# day                0.003606     0.001000
# age                0.019097    -0.001402
# dist_client_merch -0.005134     0.001070
# le_gender          0.014390    -0.010880
# te_job             0.022554     0.014038
# te_street          0.117672     0.027886
# te_merchant        0.001786     0.931719
# te_city            0.021291     0.024351
# te_state           1.000000     0.002987
# te_category        0.002987     1.000000

# %%
df_test = data_processing('../fraudTest.csv')

# %%
df_2 = df_test.drop(columns=columns_to_drop)

# %%
df_2.sample()
# Out:
#           amt    zip  city_pop   unix_time  is_fraud  year  month  day  age  \
# 65392  132.27  46346      1423  1373745964         0  2020      7   13   25
#
#        dist_client_merch  le_gender  te_job  te_street  te_merchant  te_city  \
# 65392          103.79309          0     0.0        0.0          0.0      0.0
#
#        te_state  te_category
# 65392  0.007062      0.00216

# %% [markdown]
# # Model Development

# %%
X = df_1.drop(columns=['is_fraud'])  # Features
y = df_1['is_fraud']

# %%
X_test_actual = df_2.drop(columns=['is_fraud'])  # Features
y_test_actual = df_2['is_fraud']

# %% [markdown]
# ## Data Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_unbalanced, X_test_unbalanced, y_train_unbalanced, y_test_unbalanced = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
print("X_train_unbalanced shape:", X_train_unbalanced.shape)
print("X_test_unbalanced shape:", X_test_unbalanced.shape)
print("y_train_unbalanced shape:", y_train_unbalanced.shape)
print("y_test_unbalanced shape:", y_test_unbalanced.shape)
# Out:
# X_train_unbalanced shape: (1037340, 15)
# X_test_unbalanced shape: (259335, 15)
# y_train_unbalanced shape: (1037340,)
# y_test_unbalanced shape: (259335,)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

# Define a function to measure various metrics
def measure_metrics(y_test, y_pred, y_prob=None):
    # Print accuracy score
    print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
    
    # Plot confusion matrix
    disp = metrics.ConfusionMatrixDisplay(metrics.confusion_matrix(y_test, y_pred))
    disp.plot()
    
    # Print classification report
    print(metrics.classification_report(y_test, y_pred))
    
    if y_prob is not None:
        # Calculate ROC AUC score
        roc_auc = metrics.roc_auc_score(y_test, y_prob)
        print("ROC AUC Score:", roc_auc)
        
        # Plot ROC curve
        fpr, tpr, _ = metrics.roc_curve(y_test, y_prob)
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic')
        plt.legend(loc="lower right")
        plt.show()
    else:
        print("ROC AUC and curve cannot be calculated without probability scores (y_prob).")

# Example usage
# Assuming y_test, y_pred, and y_prob are defined
# measure_metrics(y_test, y_pred, y_prob)

# %% [markdown]
# ## Model without balancing

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression(max_iter=1000)
rf = RandomForestClassifier()
gb = GradientBoostingClassifier()
svm = SVC()
dt = DecisionTreeClassifier()

# %%
lr.fit(X,y)
y_pred_lr = lr.predict(X_test_actual)
y_prob_lr = lr.predict_proba(X_test_actual)[:, 1]

# %%
measure_metrics(y_test_actual, y_pred_lr, y_prob_lr)
# Out:
# Accuracy: 0.9955139198047934
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.00      0.00      0.00      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.50      0.50      0.50    555719
# weighted avg       0.99      1.00      0.99    555719
#
# ROC AUC Score: 0.8277679024144718

# %%
dt.fit(X, y)
y_pred_dt = dt.predict(X_test_actual)
y_prob_dt = dt.predict_proba(X_test_actual)[:, 1]

# %%
measure_metrics(y_test_actual, y_pred_dt, y_prob_dt)
# Out:
# Accuracy: 0.9765007134900913
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    553574
#            1       0.06      0.37      0.11      2145
#
#     accuracy                           0.98    555719
#    macro avg       0.53      0.67      0.55    555719
# weighted avg       0.99      0.98      0.98    555719
#
# ROC AUC Score: 0.6740422724388735

# %%
rf.fit(X, y)
y_pred_rf = rf.predict(X_test_actual)
y_prob_rf = rf.predict_proba(X_test_actual)[:, 1]

# %%
measure_metrics(y_test_actual, y_pred_rf, y_prob_rf)
# Out:
# Accuracy: 0.9963650693965835
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.55      0.32      0.40      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.77      0.66      0.70    555719
# weighted avg       1.00      1.00      1.00    555719
#
# ROC AUC Score: 0.9425788040643507

# %% [markdown]
# ## Model with balancing

# %%
from imblearn.over_sampling import SMOTE

# Instantiate SMOTE
smote = SMOTE(random_state=42)

# Resample the dataset
X_train_smote, y_train_smote = smote.fit_resample(X, y)

# %% [markdown]
# ### Logistic Regression

# %%
lr.fit(X_train_smote,y_train_smote)
y_pred_lr_smote = lr.predict(X_test_actual)
y_prob_lr_smote = lr.predict_proba(X_test_actual)[:, 1]

# %%
measure_metrics(y_test_actual, y_pred_lr_smote, y_prob_lr_smote)
# Out:
# Accuracy: 0.9558014032271706
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    553574
#            1       0.06      0.75      0.12      2145
#
#     accuracy                           0.96    555719
#    macro avg       0.53      0.85      0.55    555719
# weighted avg       1.00      0.96      0.97    555719
#
# ROC AUC Score: 0.8329498915472967

# %% [markdown]
# #### Cross validation - LR

# %%
from sklearn.model_selection import cross_val_score,StratifiedKFold
from sklearn.linear_model import LogisticRegression
import numpy as np

# Instantiate the logistic regression model
lr = LogisticRegression(max_iter=1000)
skf = StratifiedKFold(n_splits=5)
# Perform cross-validation with precision as the scoring metric
cv_scores_precision = cross_val_score(lr, X_train_smote, y_train_smote, cv=skf, scoring='precision')

print("Cross-validation precision scores: ", cv_scores_precision)
print("Mean cross-validation precision score: ", np.mean(cv_scores_precision))
print("Standard deviation of cross-validation precision score: ", np.std(cv_scores_precision))
# Out:
# Cross-validation precision scores:  [0.94323049 0.94384456 0.94553631 0.94576052 0.94689058]
# Mean cross-validation precision score:  0.945052493453346
# Standard deviation of cross-validation precision score:  0.0013336204244788622

# %%
# Perform cross-validation with recall as the scoring metric
cv_scores_recall = cross_val_score(lr, X_train_smote, y_train_smote, cv=5, scoring='recall')

print("Cross-validation recall scores: ", cv_scores_recall)
print("Mean cross-validation recall score: ", np.mean(cv_scores_recall))
print("Standard deviation of cross-validation recall score: ", np.std(cv_scores_recall))
# Out:
# Cross-validation recall scores:  [0.81047496 0.81126616 0.81056028 0.81214585 0.81264302]
# Mean cross-validation recall score:  0.8114180535893996
# Standard deviation of cross-validation recall score:  0.0008577288253069143

# %%
lr.fit(X_train_smote,y_train_smote)
y_pred_lr_smote_cv = lr.predict(X_test_actual)
y_prob_lr_smote_cv = lr.predict_proba(X_test_actual)[:, 1]

# %%
measure_metrics(y_test_actual, y_pred_lr_smote_cv, y_prob_lr_smote_cv)
# Out:
# Accuracy: 0.9558014032271706
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    553574
#            1       0.06      0.75      0.12      2145
#
#     accuracy                           0.96    555719
#    macro avg       0.53      0.85      0.55    555719
# weighted avg       1.00      0.96      0.97    555719
#
# ROC AUC Score: 0.8329498915472967

# %% [markdown]
# #### Hyperpparameter tuning LR

# %%
random_search_lr = {
    'penalty': ['l1','l2','elasticnet','none'],
    'solver': ['newton-cg','lbfgs','liblinear','sag','saga'],
    'max_iter': list(np.linspace(5, 1000, 10, dtype = int)),
}

# %%
from sklearn.model_selection import RandomizedSearchCV
cv_lr = LogisticRegression(max_iter=10000)

# %%
model_lr = RandomizedSearchCV(estimator = cv_lr, param_distributions = random_search_lr, cv = 4, verbose= 5, random_state= 101, scoring='recall')

# %%
# fit logistic regression model with CV 
model_lr.fit(X_train_smote, y_train_smote)
model_lr.best_params_
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV 1/4] END max_iter=115, penalty=none, solver=liblinear;, score=nan total time=   0.2s
# [CV 2/4] END max_iter=115, penalty=none, solver=liblinear;, score=nan total time=   0.1s
# [CV 3/4] END max_iter=115, penalty=none, solver=liblinear;, score=nan total time=   0.1s
# [CV 4/4] END max_iter=115, penalty=none, solver=liblinear;, score=nan total time=   0.1s
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/4] END max_iter=557, penalty=l2, solver=saga;, score=0.132 total time= 7.0min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/4] END max_iter=557, penalty=l2, solver=saga;, score=0.197 total time= 7.1min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 3/4] END max_iter=557, penalty=l2, solver=saga;, score=0.366 total time= 6.9min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/4] END max_iter=557, penalty=l2, solver=saga;, score=0.497 total time= 6.9min
# [CV 1/4] END max_iter=115, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.2s
# [CV 2/4] END max_iter=115, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.2s
# [CV 3/4] END max_iter=115, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.2s
# [CV 4/4] END max_iter=115, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.2s
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/4] END max_iter=447, penalty=l2, solver=saga;, score=0.132 total time= 5.5min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/4] END max_iter=447, penalty=l2, solver=saga;, score=0.153 total time= 5.5min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 3/4] END max_iter=447, penalty=l2, solver=saga;, score=0.316 total time= 5.4min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/4] END max_iter=447, penalty=l2, solver=saga;, score=0.484 total time= 5.5min
# [CV 1/4] END max_iter=336, penalty=l2, solver=lbfgs;, score=0.810 total time=   7.5s
# [CV 2/4] END max_iter=336, penalty=l2, solver=lbfgs;, score=0.811 total time=   6.9s
# [CV 3/4] END max_iter=336, penalty=l2, solver=lbfgs;, score=0.812 total time=   7.0s
# [CV 4/4] END max_iter=336, penalty=l2, solver=lbfgs;, score=0.813 total time=   8.1s
# [CV 1/4] END max_iter=557, penalty=none, solver=saga;, score=nan total time=   0.2s
# [CV 2/4] END max_iter=557, penalty=none, solver=saga;, score=nan total time=   0.2s
# [CV 3/4] END max_iter=557, penalty=none, solver=saga;, score=nan total time=   0.1s
# [CV 4/4] END max_iter=557, penalty=none, solver=saga;, score=nan total time=   0.2s
# [CV 1/4] END max_iter=226, penalty=elasticnet, solver=saga;, score=nan total time=   0.1s
# [CV 2/4] END max_iter=226, penalty=elasticnet, solver=saga;, score=nan total time=   0.1s
# [CV 3/4] END max_iter=226, penalty=elasticnet, solver=saga;, score=nan total time=   0.1s
# [CV 4/4] END max_iter=226, penalty=elasticnet, solver=saga;, score=nan total time=   0.2s
# [CV 1/4] END max_iter=336, penalty=elasticnet, solver=saga;, score=nan total time=   0.1s
# [CV 2/4] END max_iter=336, penalty=elasticnet, solver=saga;, score=nan total time=   0.2s
# [CV 3/4] END max_iter=336, penalty=elasticnet, solver=saga;, score=nan total time=   0.1s
# [CV 4/4] END max_iter=336, penalty=elasticnet, solver=saga;, score=nan total time=   0.1s
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:425: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/utils/optimize.py:311: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 1/4] END max_iter=778, penalty=l2, solver=newton-cg;, score=0.819 total time= 1.2min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:425: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/utils/optimize.py:311: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/4] END max_iter=778, penalty=l2, solver=newton-cg;, score=0.818 total time= 1.6min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/utils/optimize.py:311: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 3/4] END max_iter=778, penalty=l2, solver=newton-cg;, score=0.836 total time= 4.0min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:425: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/utils/optimize.py:311: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 4/4] END max_iter=778, penalty=l2, solver=newton-cg;, score=0.821 total time= 1.1min
# /Users/SandeshShrestha/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/4] END max_iter=778, penalty=l1, solver=liblinear;, score=0.854 total time=302.5min

# %% [markdown]
# ##### Parameter tuned

# %%
para_tuned_lr = LogisticRegression(max_iter=778, penalty = 'l2', solver='newton-cg')

# %%
dt.fit(X_train_smote, y_train_smote)
y_pred_dt_smote = dt.predict(X_test_actual)
y_prob_dt_smote = dt.predict_proba(X_test_actual)[:, 1]

# %%
print('Decision Tree Result - Smote')
measure_metrics(y_test_actual, y_pred_dt_smote, y_prob_dt_smote)
# Out:
# Decision Tree Result - Smote
# Accuracy: 0.8712118894621202
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93    553574
#            1       0.01      0.23      0.01      2145
#
#     accuracy                           0.87    555719
#    macro avg       0.50      0.55      0.47    555719
# weighted avg       0.99      0.87      0.93    555719
#
# ROC AUC Score: 0.5503737842626591
